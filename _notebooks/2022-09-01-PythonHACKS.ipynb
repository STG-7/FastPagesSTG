# %% [markdown]
# # Python Lists and Dictionaries HACKS
# > Week 2 Python Lists and Dictionaries HACKS
# - toc: true
# - categories: [Week 2]

# %%
from multiprocessing.sharedctypes import Value


InfoDB = {
"FirstName": "Shaurya",
"LastName": "Goel",
"DOB": "October 29, 2007",
"Residence": "San Diego",
"Email": "shauryaggamer@gmail.com",
"Owns Cars": ["Bugatti", "Tesla"],
"Owns Devices": ["I-phone", "Gaming laptop"],
"Hobbies": ["Football", "Soccer/Basketball", "Video Games"]
}

for key in InfoDB:
        print(key +  str(InfoDB[key]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-93da70ad7eaf> in <module>
#      14
#      15 for key in InfoDB:
# ---> 16         printstr(key +  str(InfoDB[key]))
#      17
#
# NameError: name 'printstr' is not defined
