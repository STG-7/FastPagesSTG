# %% [markdown]
# # Quiz made through Python Code!
# > Good luck!

# %%
import getpass, sys

def question_with_response(prompt):
    print("Question: " + prompt)
    msg = input()
    return msg

questions = 3
correct = 0

print('Hello, ' + getpass.getuser() + " running " + sys.executable)
print("You will be asked " + str(questions) + " questions.")

rsp = question_with_response("Are you ready to take a test?")
if rsp == "yes":
    print("glad your ready, good luck!")
else:
    print("good luck!")

rsp = question_with_response("What command is used to include other functions that were previously developed?")
if rsp == "import":
    print(rsp + " is correct!")
    correct += 1
else:
    print(rsp + " is incorrect!")

rsp = question_with_response("What command is used to evaluate correct or incorrect response in this example?")
if rsp == "if":
    print(rsp + " is correct!")
    correct += 1
else:
    print(rsp + " is incorrect!")

rsp = question_with_response("Each 'if' command contains an '_________' to determine a true or false condition?")
if rsp == "expression":
    print(rsp + " is correct!")
    correct += 1
else:
    print(rsp + " is incorrect!")


print(getpass.getuser() + " you scored " + str(correct) +"/" + str(questions)) + print("In the first part")
# Out:
# Hello, shaur running C:\Users\shaur\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe
# You will be asked 3 questions.
# Question: Are you ready to take a test?
# glad your ready, good luck!
# Question: What command is used to include other functions that were previously developed?
# import is correct!
# Question: What command is used to evaluate correct or incorrect response in this example?
# if is correct!
# Question: Each 'if' command contains an '_________' to determine a true or false condition?
# expression is correct!
# shaur you scored 3/3
# In the first part
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\shaur\vscode\FastPagesSTG-1\_notebooks\2022-08-24-AQuiz.ipynb Cell 2 in <cell line: 42>()
#      <a href='vscode-notebook-cell:/c%3A/Users/shaur/vscode/FastPagesSTG-1/_notebooks/2022-08-24-AQuiz.ipynb#W1sZmlsZQ%3D%3D?line=37'>38</a> else:
#      <a href='vscode-notebook-cell:/c%3A/Users/shaur/vscode/FastPagesSTG-1/_notebooks/2022-08-24-AQuiz.ipynb#W1sZmlsZQ%3D%3D?line=38'>39</a>     print(rsp + " is incorrect!")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/shaur/vscode/FastPagesSTG-1/_notebooks/2022-08-24-AQuiz.ipynb#W1sZmlsZQ%3D%3D?line=41'>42</a> print(getpass.getuser() + " you scored " + str(correct) +"/" + str(questions)) + print("In the first part")
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'
