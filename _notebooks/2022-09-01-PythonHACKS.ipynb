# %% [markdown]
# # Python Lists and Dictionaries HACKS
# > Week 2 Python Lists and Dictionaries HACKS
# - toc: true
# - categories: [Week 2]

# %% [markdown]
# ### Defining a A List of Dictionaries Called InfoDB

# %%
# Defining a List called InfoDB that is an overall database for multiple people
InfoDB = []

# Defining people as Dictionaries that contains key-value pairs that describe them
Shaurya = {
# These records are of String type
"FirstName": "Shaurya",
"LastName": "Goel",
"DOB": "October 29, 2007",
"Residence": "San Diego",
"Email": "shauryaggamer@gmail.com",
# These records are of lists type
"Owns Cars": ["None"],
"Owns Devices": ["iPhone", "Gaming laptop"],
"Hobbies": ["Football", "Soccer", "Video Games"]
}

TomB = {
"FirstName": "Tom",
"LastName": "Brady",
"DOB": "Auguest 3, 1977",
"Residence": "Tampa Bay",
"Email": "info@brandbrady.com ",
"Owns Cars": ["2017 Aston Martin DB11", "2015 Rolls Royce Ghost", "2018 Limited Edition TB12 Aston Martin Vanquish S Volante", "2015 Ferrari M458-T", "2009 Audi R8"],
"Owns Devices": ["iPhone", "Gaming laptop"],
"Hobbies": ["Football", "Cars"]
}

# Adding the Dictionaries to the List, creaing the whole database
InfoDB.append(Shaurya)
InfoDB.append(TomB)

# %% [markdown]
# ### Iteration through InfoDB using "For Loop"

# %%
# iterate over the list of items in InfoDB list
for x in InfoDB:
    # iterate over the dictionary key - values in the items within the list (InfoDB)
    for key in x:
        print(str(key) + " : " + str(x[key]))
# Out:
# FirstName : Shaurya
# LastName : Goel
# DOB : October 29, 2007
# Residence : San Diego
# Email : shauryaggamer@gmail.com
# Owns Cars : ['None']
# Owns Devices : ['iPhone', 'Gaming laptop']
# Hobbies : ['Football', 'Soccer', 'Video Games']
# FirstName : Tom
# LastName : Brady
# DOB : Auguest 3, 1977
# Residence : Tampa Bay
# Email : info@brandbrady.com
# Owns Cars : ['2017 Aston Martin DB11', '2015 Rolls Royce Ghost', '2018 Limited Edition TB12 Aston Martin Vanquish S Volante', '2015 Ferrari M458-T', '2009 Audi R8']
# Owns Devices : ['iPhone', 'Gaming laptop']
# Hobbies : ['Football', 'Cars']

# %% [markdown]
# ### Iteration through InfoDB using "For Loop" with Indexes

# %%
# x is an integer variable
# len(InfoDB) returns length of InfoDB as an integer
# range command returns a sequence of numbers, starting from 0 by default and ends (in this case) with the length of InfoDB
for x in range(len(InfoDB)):
    # getting the dictionary stored at index position x. Naming it item
    item = InfoDB[x]
    # printing out every key and value in the dictionary using y as the index
    for y in range(len(item)):
        print(list(item)[y] +" : " + str(list(item.values())[y]))
# Out:
# FirstName : Shaurya
# LastName : Goel
# DOB : October 29, 2007
# Residence : San Diego
# Email : shauryaggamer@gmail.com
# Owns Cars : ['None']
# Owns Devices : ['iPhone', 'Gaming laptop']
# Hobbies : ['Football', 'Soccer', 'Video Games']
# FirstName : Tom
# LastName : Brady
# DOB : Auguest 3, 1977
# Residence : Tampa Bay
# Email : info@brandbrady.com
# Owns Cars : ['2017 Aston Martin DB11', '2015 Rolls Royce Ghost', '2018 Limited Edition TB12 Aston Martin Vanquish S Volante', '2015 Ferrari M458-T', '2009 Audi R8']
# Owns Devices : ['iPhone', 'Gaming laptop']
# Hobbies : ['Football', 'Cars']

# %% [markdown]
# ### Iterating through InfoDB using "While Loop"

# %%
# defining integer variable called listnumber that is assigned to 0
listnumber = 0

# setting condition that while listnumber is less than the length of InfoDB run this code:
while listnumber < len(InfoDB) :

    # Assigning a dictionary to the variable DB
    DB = InfoDB[listnumber]
    
    for key in DB:
        print(str(key) + " : " + str(DB[key]))
    
    # adding and reassigning keynumber and valuenumber so that the code will go on until all of the content in InfoDB is printed out
    listnumber += 1
# Out:
# FirstName : Shaurya
# LastName : Goel
# DOB : October 29, 2007
# Residence : San Diego
# Email : shauryaggamer@gmail.com
# Owns Cars : ['None']
# Owns Devices : ['iPhone', 'Gaming laptop']
# Hobbies : ['Football', 'Soccer', 'Video Games']
# FirstName : Tom
# LastName : Brady
# DOB : Auguest 3, 1977
# Residence : Tampa Bay
# Email : info@brandbrady.com
# Owns Cars : ['2017 Aston Martin DB11', '2015 Rolls Royce Ghost', '2018 Limited Edition TB12 Aston Martin Vanquish S Volante', '2015 Ferrari M458-T', '2009 Audi R8']
# Owns Devices : ['iPhone', 'Gaming laptop']
# Hobbies : ['Football', 'Cars']

# %% [markdown]
# ### Iteration through InfoDB Using "Recursion"

# %%
# defining a function that takes in a variables "n"
def recursive_loop(n):
    
    # setting an if statement that "if" n is less than the length of InfoDB, follow this code:
    if n < len(InfoDB):
        DB = InfoDB[n]
        # printing out the key and value in the dictionary that has the index "n"
        for key in DB:
            print(str(key) + " : " + str(DB[key]))
        
        # recursion occurs here, the function is called again but n is added and reassigned to a value one greater
        recursive_loop(n + 1)


recursive_loop(0)
# Out:
# FirstName : Shaurya
# LastName : Goel
# DOB : October 29, 2007
# Residence : San Diego
# Email : shauryaggamer@gmail.com
# Owns Cars : ['None']
# Owns Devices : ['iPhone', 'Gaming laptop']
# Hobbies : ['Football', 'Soccer', 'Video Games']
# FirstName : Tom
# LastName : Brady
# DOB : Auguest 3, 1977
# Residence : Tampa Bay
# Email : info@brandbrady.com
# Owns Cars : ['2017 Aston Martin DB11', '2015 Rolls Royce Ghost', '2018 Limited Edition TB12 Aston Martin Vanquish S Volante', '2015 Ferrari M458-T', '2009 Audi R8']
# Owns Devices : ['iPhone', 'Gaming laptop']
# Hobbies : ['Football', 'Cars']

# %% [markdown]
# ### Outputing data in InfoDB in Reverse Order

# %%
# defining integer variable called listnumber that is assigned to 0
listnumber = 0

# setting condition that while listnumber is less than the length of InfoDB run this code:
while listnumber < len(InfoDB) :

    # Assigning a dictionary to the variable DB
    DB = InfoDB[listnumber]
    
    for key in reversed(list(DB.keys())):
        print(str(key) + " : " + str(DB[key]))
    
    # adding and reassigning keynumber and valuenumber so that the code will go on until all of the content in InfoDB is printed out
    listnumber += 1
# Out:
# Hobbies : ['Football', 'Soccer', 'Video Games']
# Owns Devices : ['iPhone', 'Gaming laptop']
# Owns Cars : ['None']
# Email : shauryaggamer@gmail.com
# Residence : San Diego
# DOB : October 29, 2007
# LastName : Goel
# FirstName : Shaurya
# Hobbies : ['Football', 'Cars']
# Owns Devices : ['iPhone', 'Gaming laptop']
# Owns Cars : ['2017 Aston Martin DB11', '2015 Rolls Royce Ghost', '2018 Limited Edition TB12 Aston Martin Vanquish S Volante', '2015 Ferrari M458-T', '2009 Audi R8']
# Email : info@brandbrady.com
# Residence : Tampa Bay
# DOB : Auguest 3, 1977
# LastName : Brady
# FirstName : Tom

# %% [markdown]
# ### Adding to InfoDB using User Input

# %%
newkey = ""
newvalue = ""

def AddToDB():
    print("Add a key:")
    newkey = input()
    print("Add a value for key:")
    newvalue = input()
    InfoDB.update({newkey: newvalue})
    print("You added " + newkey + " : " + str(newvalue))

AddToDB()

print("Here is the updated InfoDB:")
for key in InfoDB:
        print(str(key) + " : " + str(InfoDB[key]))
# Out:
# Add a key:
# Add a value for key:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-7de720881863> in <module>
#      10     print("You added " + newkey + " : " + str(newvalue))
#      11
# ---> 12 AddToDB()
#      13
#      14 print("Here is the updated InfoDB:")
#
# <ipython-input-100-7de720881863> in AddToDB()
#       7     print("Add a value for key:")
#       8     newvalue = input()
# ----> 9     InfoDB.update({newkey: newvalue})
#      10     print("You added " + newkey + " : " + str(newvalue))
#      11
#
# AttributeError: 'list' object has no attribute 'update'

# %% [markdown]
# ### Removing from InfoDB using User Input

# %%
removkey = ""

def RemovToDB():
    print("Remove a key:")
    removkey = input()
    InfoDB.pop(removkey)
    print("You removed " + removkey)


RemovToDB()

print("Here is the updated InfoDB:")
for key in InfoDB:
        print(str(key) + " : " + str(InfoDB[key]))
# Out:
# Remove a key:
# You removed alternate email
# Here is the updated InfoDB:
# FirstName : Shaurya
# LastName : Goel
# DOB : October 29, 2007
# Residence : San Diego
# Email : shauryaggamer@gmail.com
# Owns Cars : ['None']
# Owns Devices : ['I-phone', 'Gaming laptop']
# Hobbies : ['Football', 'Soccer', 'Video Games']
